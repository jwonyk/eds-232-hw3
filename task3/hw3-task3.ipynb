# %% [markdown]
# # Homework 3 - Task 3: Considerations in High Dimensions
#
# This document discusses a concept from Section 6.4 of *An Introduction to Statistical Learning with Applications in Python* that I wanted clarification on and reflects on my use of generative AI to better understand the topic.

# %% [markdown]
# ## Concept to Clarify
#
# I wanted clarification on why least squares regression can perfectly fit the training data when the number of features is greater than the number of observations (p > n), and why this leads to poor performance on test data.

# %% [markdown]
# ## Prompt
#
# I am currently learning about high-dimensional data in my introductory statistical learning course and reading Section 6.4 of An Introduction to Statistical Learning with Applications in Python. I understand basic linear regression and overfitting, but I am confused about why least squares regression can perfectly (need more explanation of this part especially) fit the training data when the number of features is larger than the number of observations.
#
# Can you explain this using a simple numerical example and avoid heavy matrix notation? I would also like a comparison between what happens when (n > p) versus when (p > n), and why a perfect training fit does not necessarily mean the model is good.

# %% [markdown]
# ## Generative AI Reflection
#
# I used Claude to clarify my confusion about why least squares regression achieves perfect training fits when p > n. My initial prompt explained my background and requested a simple numerical example without heavy notation. The first response answered most of my question, though I needed one follow-up to understand why test error increases despite zero training error. The explanation aligned well with the textbook's discussion of overfitting and generalization in high dimensions, helping me connect the mathematical concepts to intuitive understanding.
